# %% [markdown]
# # Layer Skip Evaluation
#
# 在 GSM8K 上评测 Layer Skip 优化。
#
# **Layer Skip 原理：**
# - 基于 dual_cache，如果前一层的 input-output 相似度 > threshold，跳过当前层
# - 跳过时 output = input (identity mapping)
# - 上一步跳过的层，这一步必须重算（防止误差累积）
#
# **实验配置:**
# - 测试 7 种不同的 `layer_skip_threshold`: 0.950, 0.960, 0.970, 0.980, 0.990, 0.995, 0.998

# %%
import os
import torch
import gc

# Set GPU (modify as needed)
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2,3,4,5,6,7'

# Environment settings
os.environ['HF_HUB_DISABLE_SYMLINKS_WARNING'] = '1'
os.environ['HF_ALLOW_CODE_EVAL'] = '1'
os.environ['HF_DATASETS_TRUST_REMOTE_CODE'] = 'true'

# Change to llada directory
os.chdir('llada')

# Create log directory
os.makedirs('nlogs', exist_ok=True)

# Clear GPU cache
torch.cuda.empty_cache()
gc.collect()

print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"Total VRAM: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 14
#      11 os.environ['HF_DATASETS_TRUST_REMOTE_CODE'] = 'true'
#      13 # Change to llada directory
# ---> 14 os.chdir('llada')
#      16 # Create log directory
#      17 os.makedirs('nlogs', exist_ok=True)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'llada'

# %% [markdown]
# ## 1. 快速测试 (limit=30)

# %%
import subprocess
import datetime

task = "gsm8k"
fewshot = 3
limit = 30
gpu = 1

# (threshold, name)
experiments = [
    (0.985, "layer_skip_th985"),
    (0.990, "layer_skip_th990"),
    (0.995, "layer_skip_th995"),
]

for threshold, name in experiments:
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    log_file = f"nlogs/{task}_{name}_{timestamp}.log"
    
    model_args = [
        "model_path='GSAI-ML/LLaDA-8B-Instruct'",
        "gen_length=128",
        "steps=32",
        "block_length=32",
        "threshold=0.9",
        "use_cache=True",
        "layer_skip=True",
        f"layer_skip_threshold={threshold}",
        "show_speed=True",
    ]
    
    cmd = f"""CUDA_VISIBLE_DEVICES={gpu} accelerate launch eval_llada.py \\
        --tasks {task} --num_fewshot {fewshot} --limit {limit} \\
        --confirm_run_unsafe_code --model llada_dist \\
        --model_args {','.join(model_args)}"""
    
    print(f"\n{'='*60}")
    print(f"Running: {name}")
    print(f"Log file: {log_file}")
    print('='*60)
    
    with open(log_file, 'w') as f:
        result = subprocess.run(cmd, shell=True, stdout=f, stderr=subprocess.STDOUT, text=True)
    
    with open(log_file, 'r') as f:
        lines = f.readlines()
        print("Last 15 lines:")
        for line in lines[-15:]:
            print(line.rstrip())
# Out:
# ============================================================
# Running: layer_skip_th985
# Log file: nlogs/gsm8k_layer_skip_th985_20260128_230446.log
# ============================================================
# Last 15 lines:
# avg nfe:  30.966666666666665
# layer_skip_stats: computed=906, skipped=118, skip_rate=11.52%
# ====================
#
# Total number of tokens generated: 3746
# Total time taken: 69.05631685256958 seconds
# Tokens per second: 54.24557876586914
# Total NFE is 929
# Layer Skip Stats: computed=26534, skipped=3194, skip_rate=10.74%
# llada_dist (model_path=GSAI-ML/LLaDA-8B-Instruct,gen_length=128,steps=32,block_length=32,threshold=0.9,use_cache=True,layer_skip=True,layer_skip_threshold=0.985,show_speed=True), gen_kwargs: (None), limit: 30.0, num_fewshot: 3, batch_size: 1
# |Tasks|Version|     Filter     |n-shot|  Metric   |   |Value |   |Stderr|
# |-----|------:|----------------|-----:|-----------|---|-----:|---|-----:|
# |gsm8k|      3|flexible-extract|     3|exact_match|↑  |0.4333|±  |0.0920|
# |     |       |strict-match    |     3|exact_match|↑  |0.3000|±  |0.0851|
#
#
# ============================================================
# Running: layer_skip_th990
# Log file: nlogs/gsm8k_layer_skip_th990_20260128_230643.log
# ============================================================
# Last 15 lines:
# avg nfe:  30.9
# layer_skip_stats: computed=927, skipped=97, skip_rate=9.47%
# ====================
#
# Total number of tokens generated: 3722
# Total time taken: 71.37334871292114 seconds
# Tokens per second: 52.1483154296875
# Total NFE is 927
# Layer Skip Stats: computed=27156, skipped=2508, skip_rate=8.45%
# llada_dist (model_path=GSAI-ML/LLaDA-8B-Instruct,gen_length=128,steps=32,block_length=32,threshold=0.9,use_cache=True,layer_skip=True,layer_skip_threshold=0.99,show_speed=True), gen_kwargs: (None), limit: 30.0, num_fewshot: 3, batch_size: 1
# |Tasks|Version|     Filter     |n-shot|  Metric   |   |Value|   |Stderr|
# |-----|------:|----------------|-----:|-----------|---|----:|---|-----:|
# |gsm8k|      3|flexible-extract|     3|exact_match|↑  |  0.6|±  | 0.091|
# |     |       |strict-match    |     3|exact_match|↑  |  0.6|±  | 0.091|
#
#
# ============================================================
# Running: layer_skip_th995
# Log file: nlogs/gsm8k_layer_skip_th995_20260128_230836.log
# ============================================================
# Last 15 lines:
# avg nfe:  30.833333333333332
# layer_skip_stats: computed=1004, skipped=20, skip_rate=1.95%
# ====================
#
# Total number of tokens generated: 3703
# Total time taken: 73.61594581604004 seconds
# Tokens per second: 50.30160140991211
# Total NFE is 925
# Layer Skip Stats: computed=29010, skipped=590, skip_rate=1.99%
# llada_dist (model_path=GSAI-ML/LLaDA-8B-Instruct,gen_length=128,steps=32,block_length=32,threshold=0.9,use_cache=True,layer_skip=True,layer_skip_threshold=0.995,show_speed=True), gen_kwargs: (None), limit: 30.0, num_fewshot: 3, batch_size: 1
# |Tasks|Version|     Filter     |n-shot|  Metric   |   |Value |   |Stderr|
# |-----|------:|----------------|-----:|-----------|---|-----:|---|-----:|
# |gsm8k|      3|flexible-extract|     3|exact_match|↑  |0.5000|±  |0.0928|
# |     |       |strict-match    |     3|exact_match|↑  |0.4333|±  |0.0920|

# %%
torch.cuda.empty_cache()

# %% [markdown]
# ## 2. 并行完整测试（7个 threshold）

# %%
import subprocess
import datetime

task = "gsm8k"
fewshot = 3
limit = 500
# (threshold, gpu, name)
# 7个不同的 layer_skip_threshold 值
configs = [
    (1.00, 7, "layer_skip_th977"),
    (0.95, 1, "layer_skip_th976"),
    (0.96, 3, "layer_skip_th9817"),
    (0.97, 4, "layer_skip_th980"),
    (0.98, 5, "layer_skip_th9815"),
    (0.99, 6, "layer_skip_th982"),
]

processes = []

for threshold, gpu, name in configs:
    log_file = f"nlogs/layer_skip_{task}_{name}_{datetime.datetime.now():%F_%H-%M-%S}.log"
    
    model_args = [
        "model_path='GSAI-ML/LLaDA-8B-Instruct'",
        "gen_length=128",
        "steps=32",
        "block_length=32",
        "threshold=0.9",
        "use_cache=True",
        "layer_skip=True",
        f"layer_skip_threshold={threshold}",
        "show_speed=True",
    ]
    
    cmd = f"""CUDA_VISIBLE_DEVICES={gpu} accelerate launch eval_llada.py \\
        --tasks {task} --num_fewshot {fewshot} --limit {limit}\\
        --confirm_run_unsafe_code --model llada_dist \\
        --model_args {','.join(model_args)} \\
        --output_path evals_results/layer_skip/gsm8k-{name} --log_samples"""
    
    print(f"GPU{gpu} running: {name} (threshold={threshold})")
    p = subprocess.Popen(cmd, shell=True, stdout=open(log_file, "w"), stderr=subprocess.STDOUT)
    processes.append((p, name, log_file))

print(f"\n{len(processes)} tasks launched, waiting...")

for p, name, log in processes:
    p.wait()
    print(f"{name} finished (exit code: {p.returncode})")

# %%
import subprocess
import datetime

task = "gsm8k"
fewshot = 3
limit = 500
# (threshold, gpu, name)
# 7个不同的 layer_skip_threshold 值
configs = [
    (0.977, 7, "layer_skip_th977"),
    (0.976, 1, "layer_skip_th976"),
    (0.9815, 3, "layer_skip_th9817"),
    (0.980, 4, "layer_skip_th980"),
    (0.9815, 5, "layer_skip_th9815"),
    (0.982, 6, "layer_skip_th982"),
]

processes = []

for threshold, gpu, name in configs:
    log_file = f"nlogs/layer_skip_{task}_{name}_{datetime.datetime.now():%F_%H-%M-%S}.log"
    
    model_args = [
        "model_path='GSAI-ML/LLaDA-8B-Instruct'",
        "gen_length=128",
        "steps=32",
        "block_length=32",
        "threshold=0.9",
        "use_cache=True",
        "layer_skip=True",
        f"layer_skip_threshold={threshold}",
        "show_speed=True",
    ]
    
    cmd = f"""CUDA_VISIBLE_DEVICES={gpu} accelerate launch eval_llada.py \\
        --tasks {task} --num_fewshot {fewshot} --limit {limit}\\
        --confirm_run_unsafe_code --model llada_dist \\
        --model_args {','.join(model_args)} \\
        --output_path evals_results/layer_skip/gsm8k-{name} --log_samples"""
    
    print(f"GPU{gpu} running: {name} (threshold={threshold})")
    p = subprocess.Popen(cmd, shell=True, stdout=open(log_file, "w"), stderr=subprocess.STDOUT)
    processes.append((p, name, log_file))

print(f"\n{len(processes)} tasks launched, waiting...")

for p, name, log in processes:
    p.wait()
    print(f"{name} finished (exit code: {p.returncode})")
# Out:
# GPU7 running: layer_skip_th977 (threshold=0.977)
# GPU1 running: layer_skip_th976 (threshold=0.976)
# GPU3 running: layer_skip_th9817 (threshold=0.9815)
# GPU4 running: layer_skip_th980 (threshold=0.98)
# GPU5 running: layer_skip_th9815 (threshold=0.9815)
# GPU6 running: layer_skip_th982 (threshold=0.982)
#
# 6 tasks launched, waiting...
# layer_skip_th977 finished (exit code: 0)
# layer_skip_th976 finished (exit code: 0)
# layer_skip_th9817 finished (exit code: 0)
# layer_skip_th980 finished (exit code: 0)
# layer_skip_th9815 finished (exit code: 0)
# layer_skip_th982 finished (exit code: 0)

# %%
import subprocess
import datetime

task = "gsm8k"
fewshot = 3
limit = 500
# (threshold, gpu, name)
# 7个不同的 layer_skip_threshold 值
configs = [
    (0.974, 7, "layer_skip_th974"),
    (0.973, 1, "layer_skip_th973"),
    (0.972, 3, "layer_skip_th972"),
    (0.971, 4, "layer_skip_th971"),
    (0.960, 5, "layer_skip_th960"),
    (0.965, 6, "layer_skip_th965"),
]

processes = []

for threshold, gpu, name in configs:
    log_file = f"nlogs/layer_skip_{task}_{name}_{datetime.datetime.now():%F_%H-%M-%S}.log"
    
    model_args = [
        "model_path='GSAI-ML/LLaDA-8B-Instruct'",
        "gen_length=128",
        "steps=32",
        "block_length=32",
        "threshold=0.9",
        "use_cache=True",
        "layer_skip=True",
        f"layer_skip_threshold={threshold}",
        "show_speed=True",
    ]
    
    cmd = f"""CUDA_VISIBLE_DEVICES={gpu} accelerate launch eval_llada.py \\
        --tasks {task} --num_fewshot {fewshot} --limit {limit}\\
        --confirm_run_unsafe_code --model llada_dist \\
        --model_args {','.join(model_args)} \\
        --output_path evals_results/layer_skip/gsm8k-{name} --log_samples"""
    
    print(f"GPU{gpu} running: {name} (threshold={threshold})")
    p = subprocess.Popen(cmd, shell=True, stdout=open(log_file, "w"), stderr=subprocess.STDOUT)
    processes.append((p, name, log_file))

print(f"\n{len(processes)} tasks launched, waiting...")

for p, name, log in processes:
    p.wait()
    print(f"{name} finished (exit code: {p.returncode})")
# Out:
# GPU7 running: layer_skip_th974 (threshold=0.974)
# GPU1 running: layer_skip_th973 (threshold=0.973)
# GPU3 running: layer_skip_th972 (threshold=0.972)
# GPU4 running: layer_skip_th971 (threshold=0.971)
# GPU5 running: layer_skip_th960 (threshold=0.96)
# GPU6 running: layer_skip_th965 (threshold=0.965)
#
# 6 tasks launched, waiting...
# layer_skip_th974 finished (exit code: 0)
# layer_skip_th973 finished (exit code: 0)
# layer_skip_th972 finished (exit code: 0)
# layer_skip_th971 finished (exit code: 0)
# layer_skip_th960 finished (exit code: 0)
# layer_skip_th965 finished (exit code: 0)

# %%
import subprocess
import datetime

task = "gsm8k"
fewshot = 3
limit = 500
# (threshold, gpu, name)
# 7个不同的 layer_skip_threshold 值
configs = [
    (0.969, 7, "layer_skip_th969"),
    (0.968, 1, "layer_skip_th968"),
    (0.967, 3, "layer_skip_th967"),
    (0.966, 4, "layer_skip_th966"),
    (0.964, 5, "layer_skip_th964"),
    (0.963, 6, "layer_skip_th963"),
]

processes = []

for threshold, gpu, name in configs:
    log_file = f"nlogs/layer_skip_{task}_{name}_{datetime.datetime.now():%F_%H-%M-%S}.log"
    
    model_args = [
        "model_path='GSAI-ML/LLaDA-8B-Instruct'",
        "gen_length=128",
        "steps=32",
        "block_length=32",
        "threshold=0.9",
        "use_cache=True",
        "layer_skip=True",
        f"layer_skip_threshold={threshold}",
        "show_speed=True",
    ]
    
    cmd = f"""CUDA_VISIBLE_DEVICES={gpu} accelerate launch eval_llada.py \\
        --tasks {task} --num_fewshot {fewshot} --limit {limit}\\
        --confirm_run_unsafe_code --model llada_dist \\
        --model_args {','.join(model_args)} \\
        --output_path evals_results/layer_skip/gsm8k-{name} --log_samples"""
    
    print(f"GPU{gpu} running: {name} (threshold={threshold})")
    p = subprocess.Popen(cmd, shell=True, stdout=open(log_file, "w"), stderr=subprocess.STDOUT)
    processes.append((p, name, log_file))

print(f"\n{len(processes)} tasks launched, waiting...")

for p, name, log in processes:
    p.wait()
    print(f"{name} finished (exit code: {p.returncode})")
# Out:
# GPU7 running: layer_skip_th969 (threshold=0.969)
# GPU1 running: layer_skip_th968 (threshold=0.968)
# GPU3 running: layer_skip_th967 (threshold=0.967)
# GPU4 running: layer_skip_th966 (threshold=0.966)
# GPU5 running: layer_skip_th964 (threshold=0.964)
# GPU6 running: layer_skip_th963 (threshold=0.963)
#
# 6 tasks launched, waiting...
# layer_skip_th969 finished (exit code: 0)
# layer_skip_th968 finished (exit code: 0)
# layer_skip_th967 finished (exit code: 0)
# layer_skip_th966 finished (exit code: 0)
# layer_skip_th964 finished (exit code: 0)
# layer_skip_th963 finished (exit code: 0)

# %%
import subprocess
import datetime

task = "gsm8k"
fewshot = 3
limit = 500
# (threshold, gpu, name)
# 7个不同的 layer_skip_threshold 值
configs = [
    (0.962, 7, "layer_skip_th962"),
    (0.961, 1, "layer_skip_th961"),
    (0.959, 3, "layer_skip_th959"),
    (0.956, 4, "layer_skip_th956"),
    (0.953, 5, "layer_skip_th953"),
    (0.951, 6, "layer_skip_th951"),
]

processes = []

for threshold, gpu, name in configs:
    log_file = f"nlogs/layer_skip_{task}_{name}_{datetime.datetime.now():%F_%H-%M-%S}.log"
    
    model_args = [
        "model_path='GSAI-ML/LLaDA-8B-Instruct'",
        "gen_length=128",
        "steps=32",
        "block_length=32",
        "threshold=0.9",
        "use_cache=True",
        "layer_skip=True",
        f"layer_skip_threshold={threshold}",
        "show_speed=True",
    ]
    
    cmd = f"""CUDA_VISIBLE_DEVICES={gpu} accelerate launch eval_llada.py \\
        --tasks {task} --num_fewshot {fewshot} --limit {limit}\\
        --confirm_run_unsafe_code --model llada_dist \\
        --model_args {','.join(model_args)} \\
        --output_path evals_results/layer_skip/gsm8k-{name} --log_samples"""
    
    print(f"GPU{gpu} running: {name} (threshold={threshold})")
    p = subprocess.Popen(cmd, shell=True, stdout=open(log_file, "w"), stderr=subprocess.STDOUT)
    processes.append((p, name, log_file))

print(f"\n{len(processes)} tasks launched, waiting...")

for p, name, log in processes:
    p.wait()
    print(f"{name} finished (exit code: {p.returncode})")
# Out:
# GPU7 running: layer_skip_th962 (threshold=0.962)
# GPU1 running: layer_skip_th961 (threshold=0.961)
# GPU3 running: layer_skip_th959 (threshold=0.959)
# GPU4 running: layer_skip_th956 (threshold=0.956)
# GPU5 running: layer_skip_th953 (threshold=0.953)
# GPU6 running: layer_skip_th951 (threshold=0.951)
#
# 6 tasks launched, waiting...
# layer_skip_th962 finished (exit code: 0)
# layer_skip_th961 finished (exit code: 1)
# layer_skip_th959 finished (exit code: 0)
# layer_skip_th956 finished (exit code: 0)
# layer_skip_th953 finished (exit code: 0)
# layer_skip_th951 finished (exit code: 0)

# %% [markdown]
# ## 3. 查看结果

# %%
import glob
import re
import os

log_files = sorted(glob.glob("nlogs/layer_skip_gsm8k*.log"), key=os.path.getmtime, reverse=True)

print("Layer Skip GSM8K Results:")
print("=" * 110)

results = []
for log_file in log_files:  # 最近14个（7个threshold × 可能多次运行）
    name = os.path.basename(log_file)
    
    with open(log_file, 'r') as f:
        content = f.read()
    
    # Accuracy - 匹配表格格式: |flexible-extract|...|0.566|±|
    # 格式: |gsm8k|      3|flexible-extract|     3|exact_match|↑  |0.566|±  |0.0222|
    acc_match = re.search(r'flexible-extract.*?\|(\d+\.\d+)\|±', content)
    acc = float(acc_match.group(1)) * 100 if acc_match else None
    
    # Speed
    speed_match = re.search(r'Tokens per second:\s*([\d.]+)', content)
    speed = float(speed_match.group(1)) if speed_match else None
    
    # NFE
    nfe_match = re.search(r'Total NFE is (\d+)', content)
    nfe = int(nfe_match.group(1)) if nfe_match else None
    
    # Time
    time_match = re.search(r'Total time taken:\s*([\d.]+)', content)
    time_sec = float(time_match.group(1)) if time_match else None
    
    # Layer Skip Rate (从最终汇总中提取)
    skip_match = re.search(r'Layer Skip Stats:.*skip_rate=([\d.]+)%', content)
    skip_rate = float(skip_match.group(1)) if skip_match else None
    
    # Layers computed/skipped
    computed_match = re.search(r'Layer Skip Stats: computed=(\d+)', content)
    skipped_match = re.search(r'skipped=(\d+)', content)
    computed = int(computed_match.group(1)) if computed_match else None
    skipped = int(skipped_match.group(1)) if skipped_match else None
    
    results.append({
        'name': name,
        'accuracy': acc,
        'tokens_per_sec': speed,
        'total_nfe': nfe,
        'time_sec': time_sec,
        'skip_rate': skip_rate,
        'layers_computed': computed,
        'layers_skipped': skipped,
    })

print(f"{'Name':<55} {'Acc%':<8} {'Tok/s':<10} {'NFE':<10} {'Time(s)':<10} {'Skip%':<8} {'Computed':<10} {'Skipped':<10}")
print("-" * 110)
for r in results:
    acc_str = f"{r['accuracy']:.2f}" if r['accuracy'] else "N/A"
    speed_str = f"{r['tokens_per_sec']:.1f}" if r['tokens_per_sec'] else "N/A"
    nfe_str = str(r['total_nfe']) if r['total_nfe'] else "N/A"
    time_str = f"{r['time_sec']:.1f}" if r['time_sec'] else "N/A"
    skip_str = f"{r['skip_rate']:.2f}" if r['skip_rate'] else "N/A"
    computed_str = str(r['layers_computed']) if r['layers_computed'] else "N/A"
    skipped_str = str(r['layers_skipped']) if r['layers_skipped'] else "N/A"
    print(f"{r['name']:<55} {acc_str:<8} {speed_str:<10} {nfe_str:<10} {time_str:<10} {skip_str:<8} {computed_str:<10} {skipped_str:<10}")
# Out:
# Layer Skip GSM8K Results:
# ==============================================================================================================
# Name                                                    Acc%     Tok/s      NFE        Time(s)    Skip%    Computed   Skipped
# --------------------------------------------------------------------------------------------------------------
# layer_skip_gsm8k_layer_skip_th962_2026-01-29_13-50-30.log 10.80    49.0       14026      1031.0     23.87    341714     127
# layer_skip_gsm8k_layer_skip_th959_2026-01-29_13-50-30.log 7.40     45.8       13149      981.1      25.03    315457     100
# layer_skip_gsm8k_layer_skip_th956_2026-01-29_13-50-30.log 5.80     44.1       12482      939.3      26.09    295212     65
# layer_skip_gsm8k_layer_skip_th951_2026-01-29_13-50-30.log 5.00     43.0       12137      920.4      28.07    279367     311
# layer_skip_gsm8k_layer_skip_th953_2026-01-29_13-50-30.log 6.20     42.5       11953      914.0      26.95    279420     182
# layer_skip_gsm8k_layer_skip_th961_2026-01-29_13-50-30.log N/A      N/A        N/A        N/A        N/A      N/A        N/A
# layer_skip_gsm8k_layer_skip_th969_2026-01-29_13-30-55.log 24.80    52.7       15412      1133.0     20.31    393024     216
# layer_skip_gsm8k_layer_skip_th967_2026-01-29_13-30-55.log 19.00    52.3       15256      1119.5     21.14    385012     220
# layer_skip_gsm8k_layer_skip_th966_2026-01-29_13-30-55.log N/A      52.1       15137      1113.2     21.60    379759     243
# layer_skip_gsm8k_layer_skip_th964_2026-01-29_13-30-55.log 14.20    50.6       14542      1072.6     22.63    360032     152
# layer_skip_gsm8k_layer_skip_th963_2026-01-29_13-30-55.log 13.20    49.7       14389      1067.7     23.33    353044     120
# layer_skip_gsm8k_layer_skip_th968_2026-01-29_13-30-55.log 18.40    56.1       15300      1052.8     20.70    388240     168
# layer_skip_gsm8k_layer_skip_th974_2026-01-29_13-11-07.log 26.60    52.5       15468      1144.1     19.10    400431     196
# layer_skip_gsm8k_layer_skip_th972_2026-01-29_13-11-07.log 24.00    52.6       15484      1143.5     19.53    398708     222
# layer_skip_gsm8k_layer_skip_th971_2026-01-29_13-11-07.log 22.40    52.7       15481      1142.4     19.72    397710     205
# layer_skip_gsm8k_layer_skip_th965_2026-01-29_13-11-07.log 17.40    51.4       15000      1106.5     22.11    373882     175
# layer_skip_gsm8k_layer_skip_th973_2026-01-29_13-11-07.log 27.00    55.8       15489      1076.7     19.34    399796     196
# layer_skip_gsm8k_layer_skip_th960_2026-01-29_13-11-07.log 9.20     46.3       13413      1004.1     24.66    323355     100
# layer_skip_gsm8k_layer_skip_th982_2026-01-29_12-50-01.log 45.40    50.5       15609      1224.4     12.88    435163     134
# layer_skip_gsm8k_layer_skip_th9815_2026-01-29_12-50-01.log 43.00    50.6       15516      1209.5     13.73    428343     135
# layer_skip_gsm8k_layer_skip_th9817_2026-01-29_12-50-01.log 43.00    51.0       15516      1198.0     13.73    428343     135
# layer_skip_gsm8k_layer_skip_th980_2026-01-29_12-50-01.log 31.60    51.0       15235      1160.4     16.99    404711     142
# layer_skip_gsm8k_layer_skip_th977_2026-01-29_12-50-01.log 24.40    51.5       15198      1141.5     18.34    397152     190
# layer_skip_gsm8k_layer_skip_th976_2026-01-29_12-50-01.log 27.20    55.3       15214      1066.4     18.52    396701     191
# layer_skip_gsm8k_layer_skip_th100_2026-01-29_12-20-38.log 56.60    46.4       15566      1342.8     N/A      498112     N/A
# layer_skip_gsm8k_layer_skip_th992_2026-01-29_12-20-38.log 51.40    48.5       15548      1272.1     6.24     466468     66
# layer_skip_gsm8k_layer_skip_th988_2026-01-29_12-20-38.log 48.60    49.7       15489      1236.9     9.74     447362     107
# layer_skip_gsm8k_layer_skip_th983_2026-01-29_12-20-38.log 48.00    50.7       15594      1222.8     11.94    439413     127
# layer_skip_gsm8k_layer_skip_th975_2026-01-29_12-20-38.log 28.40    52.3       15381      1143.7     18.78    399739     191
# layer_skip_gsm8k_layer_skip_th981_2026-01-29_12-20-38.log 35.60    54.6       15431      1108.1     15.04    419543     138
# layer_skip_gsm8k_layer_skip_th999_2026-01-28_23-48-25.log 56.60    46.5       15566      1339.3     N/A      498112     N/A
# layer_skip_gsm8k_layer_skip_th997_2026-01-28_23-48-25.log 55.60    46.8       15565      1331.2     0.19     497109     3
# layer_skip_gsm8k_layer_skip_th991_2026-01-28_23-48-25.log 48.40    48.9       15581      1259.1     7.59     460736     78
# layer_skip_gsm8k_layer_skip_th993_2026-01-28_23-48-25.log 53.20    51.3       15565      1204.2     4.77     474315     54
# layer_skip_gsm8k_layer_skip_th998_2026-01-28_23-14-59.log 56.40    46.3       15566      1343.4     0.01     498086     N/A
# layer_skip_gsm8k_layer_skip_th995_2026-01-28_23-14-59.log 54.60    47.2       15608      1318.6     1.99     489508     28
# layer_skip_gsm8k_layer_skip_th990_2026-01-28_23-14-59.log 48.40    49.0       15522      1253.0     8.56     454205     90
# layer_skip_gsm8k_layer_skip_th985_2026-01-28_23-14-59.log 48.20    50.4       15570      1228.7     10.75    444681     112
# layer_skip_gsm8k_layer_skip_th970_2026-01-28_23-14-59.log 21.40    56.2       15478      1068.1     20.02    396131     208
# layer_skip_gsm8k_layer_skip_th950_2026-01-28_23-14-59.log 6.20     44.2       12305      910.1      28.64    280971     72

# %% [markdown]
# ## 4. 手动运行（可选）

# %% [markdown]
# ## MBPP 测试 - GPU 池子 + Threshold 队列

# %%
import subprocess
import datetime
import threading
import queue
import time

# ============== 配置区 ==============
task = "mbpp"
fewshot = 3
limit = None  # None = 全量测试

# GPU 池子 - 可用的 GPU 列表
gpu_pool = [0, 1, 3, 4, 5, 6, 7]

# Threshold 池子 - 所有要测试的 threshold 值
# 从 GSM8K 实验中使用的所有 threshold
threshold_pool = [
    # 高阈值（保守跳过）
    1.000, 0.999, 0.998, 0.997, 0.995,
    # 中等阈值
    0.993, 0.991, 0.990, 0.987, 0.985, 0.982, 0.9815, 0.980,
    0.977, 0.976, 0.974, 0.973, 0.972, 0.971,
    # 低阈值（激进跳过）
    0.970, 0.969, 0.968, 0.967, 0.966, 0.965, 0.964, 0.963,
    0.962, 0.961, 0.960, 0.959, 0.956, 0.953, 0.951, 0.950,
]

# ============== 任务队列 ==============
task_queue = queue.Queue()
for th in threshold_pool:
    task_queue.put(th)

results_lock = threading.Lock()
results = []

def get_threshold_name(th):
    """根据 threshold 生成文件名后缀，如 0.985 -> th985, 0.9815 -> th9815"""
    # 去掉小数点，保留有效数字
    th_str = f"{th:.4f}".rstrip('0').replace('.', '')
    return f"th{th_str}"

def worker(gpu_id):
    """每个 GPU 的工作线程"""
    while True:
        try:
            threshold = task_queue.get_nowait()
        except queue.Empty:
            break
        
        name = f"layer_skip_{get_threshold_name(threshold)}"
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        log_file = f"nlogs/layer_skip_{task}_{name}_{timestamp}.log"
        
        model_args = [
            "model_path='GSAI-ML/LLaDA-8B-Instruct'",
            "gen_length=512",
            "steps=512",
            "block_length=32",
            "threshold=0.9",
            "use_cache=True",
            "layer_skip=True",
            f"layer_skip_threshold={threshold}",
            "show_speed=True",
        ]
        
        limit_arg = f"--limit {limit}" if limit else ""
        
        cmd = f"""CUDA_VISIBLE_DEVICES={gpu_id} accelerate launch eval_llada.py \\
            --tasks {task} --num_fewshot {fewshot} {limit_arg} \\
            --confirm_run_unsafe_code --model llada_dist \\
            --model_args {','.join(model_args)} \\
            --output_path evals_results/layer_skip/{task}-{name} --log_samples"""
        
        print(f"[GPU {gpu_id}] 开始: threshold={threshold} -> {log_file}")
        start_time = time.time()
        
        with open(log_file, 'w') as f:
            result = subprocess.run(cmd, shell=True, stdout=f, stderr=subprocess.STDOUT)
        
        elapsed = time.time() - start_time
        print(f"[GPU {gpu_id}] 完成: threshold={threshold}, 耗时={elapsed/60:.1f}分钟, exit_code={result.returncode}")
        
        with results_lock:
            results.append({
                'gpu': gpu_id,
                'threshold': threshold,
                'log_file': log_file,
                'exit_code': result.returncode,
                'elapsed_min': elapsed / 60
            })
        
        task_queue.task_done()

# ============== 启动所有 GPU worker ==============
print(f"任务总数: {len(threshold_pool)}")
print(f"可用 GPU: {gpu_pool}")
print(f"Task: {task}, fewshot: {fewshot}, limit: {limit}")
print("=" * 60)

threads = []
for gpu_id in gpu_pool:
    t = threading.Thread(target=worker, args=(gpu_id,))
    t.start()
    threads.append(t)
    time.sleep(2)  # 错开启动，避免同时加载模型

# 等待所有任务完成
for t in threads:
    t.join()

print("\n" + "=" * 60)
print("所有任务完成！")
print(f"成功: {sum(1 for r in results if r['exit_code'] == 0)}/{len(results)}")

# 按 threshold 排序显示结果
results.sort(key=lambda x: x['threshold'], reverse=True)
print(f"\n{'Threshold':<12} {'GPU':<6} {'耗时(分)':<12} {'Exit':<6} {'Log File'}")
print("-" * 80)
for r in results:
    print(f"{r['threshold']:<12.4f} {r['gpu']:<6} {r['elapsed_min']:<12.1f} {r['exit_code']:<6} {r['log_file']}")

# %% [markdown]
# ## MBPP 结果查看

# %%
import glob
import re
import os

log_files = sorted(glob.glob("nlogs/layer_skip_mbpp*.log"), key=os.path.getmtime, reverse=True)

print("Layer Skip MBPP Results:")
print("=" * 120)

mbpp_results = []
for log_file in log_files[:50]:  # 最近50个
    name = os.path.basename(log_file)
    
    with open(log_file, 'r') as f:
        content = f.read()
    
    # MBPP 使用 pass@1 指标，格式: |mbpp|...|pass@1,none|...|0.xxx|
    # 尝试匹配 pass@1
    acc_match = re.search(r'pass@1.*?\|(\d+\.\d+)\|±', content)
    if not acc_match:
        # 备用：匹配任何数值
        acc_match = re.search(r'\|mbpp\|.*?\|(\d+\.\d+)\|±', content)
    acc = float(acc_match.group(1)) * 100 if acc_match else None
    
    # Speed
    speed_match = re.search(r'Tokens per second:\s*([\d.]+)', content)
    speed = float(speed_match.group(1)) if speed_match else None
    
    # NFE
    nfe_match = re.search(r'Total NFE is (\d+)', content)
    nfe = int(nfe_match.group(1)) if nfe_match else None
    
    # Time
    time_match = re.search(r'Total time taken:\s*([\d.]+)', content)
    time_sec = float(time_match.group(1)) if time_match else None
    
    # Layer Skip Rate
    skip_match = re.search(r'Layer Skip Stats:.*skip_rate=([\d.]+)%', content)
    skip_rate = float(skip_match.group(1)) if skip_match else None
    
    # 从文件名提取 threshold
    th_match = re.search(r'th(\d+)', name)
    if th_match:
        th_str = th_match.group(1)
        # 还原 threshold: th985 -> 0.985, th9815 -> 0.9815
        if len(th_str) == 3:
            threshold = int(th_str) / 1000
        elif len(th_str) == 4:
            threshold = int(th_str) / 10000
        else:
            threshold = float(f"0.{th_str}")
    else:
        threshold = None
    
    mbpp_results.append({
        'name': name,
        'threshold': threshold,
        'accuracy': acc,
        'tokens_per_sec': speed,
        'total_nfe': nfe,
        'time_sec': time_sec,
        'skip_rate': skip_rate,
    })

# 按 threshold 排序
mbpp_results.sort(key=lambda x: x['threshold'] if x['threshold'] else 0, reverse=True)

print(f"{'Name':<55} {'Thresh':<8} {'Acc%':<8} {'Tok/s':<10} {'NFE':<10} {'Time(s)':<10} {'Skip%':<8}")
print("-" * 120)
for r in mbpp_results:
    th_str = f"{r['threshold']:.4f}" if r['threshold'] else "N/A"
    acc_str = f"{r['accuracy']:.2f}" if r['accuracy'] else "N/A"
    speed_str = f"{r['tokens_per_sec']:.1f}" if r['tokens_per_sec'] else "N/A"
    nfe_str = str(r['total_nfe']) if r['total_nfe'] else "N/A"
    time_str = f"{r['time_sec']:.1f}" if r['time_sec'] else "N/A"
    skip_str = f"{r['skip_rate']:.2f}" if r['skip_rate'] else "N/A"
    print(f"{r['name']:<55} {th_str:<8} {acc_str:<8} {speed_str:<10} {nfe_str:<10} {time_str:<10} {skip_str:<8}")

# %%
# MBPP Acc vs Skip Rate 可视化
import matplotlib.pyplot as plt

# 从 mbpp_results 中提取有效数据
plot_data = []
for r in mbpp_results:
    acc = r['accuracy']
    skip = r['skip_rate'] if r['skip_rate'] is not None else 0.0
    th = r['threshold']
    if acc is not None and th is not None:
        plot_data.append({
            'threshold': th,
            'accuracy': acc,
            'skip_rate': skip,
        })

# 按 skip_rate 排序
plot_data.sort(key=lambda x: x['skip_rate'])

if plot_data:
    skip_rates = [d['skip_rate'] for d in plot_data]
    accuracies = [d['accuracy'] for d in plot_data]

    fig, ax = plt.subplots(figsize=(10, 6))
    ax.plot(skip_rates, accuracies, 'bo-', linewidth=2, markersize=10)

    # 标注每个点的 threshold
    for i, d in enumerate(plot_data):
        th_label = f"{d['threshold']:.3f}"
        ax.annotate(th_label, (skip_rates[i], accuracies[i]), 
                    textcoords="offset points", xytext=(0, 10), ha='center', fontsize=8)

    ax.set_xlabel('Layer Skip Rate (%)', fontsize=12)
    ax.set_ylabel('Pass@1 (%)', fontsize=12)
    ax.set_title('MBPP Pass@1 vs Layer Skip Rate', fontsize=14)
    ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig('nlogs/mbpp_acc_vs_skip_rate.png', dpi=150)
    plt.show()
    
    print("\n图表已保存至 nlogs/mbpp_acc_vs_skip_rate.png")
    
    # 打印数据表格
    print("\n" + "="*60)
    print(f"{'Threshold':<12} {'Skip Rate %':<15} {'Pass@1 %':<15}")
    print("-"*60)
    for d in plot_data:
        print(f"{d['threshold']:<12.4f} {d['skip_rate']:<15.2f} {d['accuracy']:<15.2f}")
else:
    print("没有找到有效的 MBPP 结果数据")

# %%
import matplotlib.pyplot as plt
import numpy as np

# 从 results 中提取有效数据
# 将 N/A 的 skip_rate 视为 0
plot_data = []
for r in results:
    acc = r['accuracy']
    skip = r['skip_rate'] if r['skip_rate'] is not None else 0.0
    if acc is not None:
        # 从文件名提取 threshold
        th_match = re.search(r'th(\d+)', r['name'])
        th = int(th_match.group(1)) / 1000 if th_match else 0
        plot_data.append({
            'threshold': th,
            'accuracy': acc,
            'skip_rate': skip,
            'name': r['name']
        })

# 按 skip_rate 排序
plot_data.sort(key=lambda x: x['skip_rate'])

skip_rates = [d['skip_rate'] for d in plot_data]
accuracies = [d['accuracy'] for d in plot_data]
thresholds = [d['threshold'] for d in plot_data]

# 创建图表
fig, ax = plt.subplots(figsize=(10, 6))

# 散点图 + 连线
ax.plot(skip_rates, accuracies, 'bo-', linewidth=2, markersize=10, label='Accuracy')

# 标注每个点的 threshold
for i, d in enumerate(plot_data):
    th_label = f"{d['threshold']:.3f}"
    ax.annotate(th_label, (skip_rates[i], accuracies[i]), 
                textcoords="offset points", xytext=(0, 10), ha='center', fontsize=8)

ax.set_xlabel('Layer Skip Rate (%)', fontsize=12)
ax.set_ylabel('Accuracy (%)', fontsize=12)
ax.set_title('Accuracy vs Layer Skip Rate (GSM8K)', fontsize=14)
ax.grid(True, alpha=0.3)
ax.set_xlim(-1, max(skip_rates) + 3)
ax.set_ylim(0, 65)

# 添加参考线

plt.tight_layout()
plt.savefig('nlogs/acc_vs_skip_rate.png', dpi=150)
plt.show()

print("\n图表已保存至 nlogs/acc_vs_skip_rate.png")

# 打印数据表格
print("\n" + "="*60)
print(f"{'Threshold':<12} {'Skip Rate %':<15} {'Accuracy %':<15}")
print("-"*60)
for d in plot_data:
    print(f"{d['threshold']:<12.3f} {d['skip_rate']:<15.2f} {d['accuracy']:<15.2f}")
# Out:
# 图表已保存至 nlogs/acc_vs_skip_rate.png
#
# ============================================================
# Threshold    Skip Rate %     Accuracy %
# ------------------------------------------------------------
# 0.100        0.00            56.60
# 0.999        0.00            56.60
# 0.998        0.01            56.40
# 0.997        0.19            55.60
# 0.995        1.99            54.60
# 0.993        4.77            53.20
# 0.992        6.24            51.40
# 0.991        7.59            48.40
# 0.990        8.56            48.40
# 0.988        9.74            48.60
# 0.985        10.75           48.20
# 0.983        11.94           48.00
# 0.982        12.88           45.40
# 9.815        13.73           43.00
# 9.817        13.73           43.00
# 0.981        15.04           35.60
# 0.980        16.99           31.60
# 0.977        18.34           24.40
# 0.976        18.52           27.20
# 0.975        18.78           28.40
# 0.974        19.10           26.60
# 0.973        19.34           27.00
# 0.972        19.53           24.00
# 0.971        19.72           22.40
# 0.970        20.02           21.40
# 0.969        20.31           24.80
# 0.968        20.70           18.40
# 0.967        21.14           19.00
# 0.965        22.11           17.40
# 0.964        22.63           14.20
# 0.963        23.33           13.20
# 0.962        23.87           10.80
# 0.960        24.66           9.20
# 0.959        25.03           7.40
# 0.956        26.09           5.80
# 0.953        26.95           6.20
# 0.951        28.07           5.00
# 0.950        28.64           6.20

# %%
# Single experiment
import subprocess
import datetime

threshold = 0.990  # 修改此值测试不同阈值
limit = 100
gpu = 0

name = f"manual_layer_skip_th{int(threshold*1000)}"
log_file = f"nlogs/manual_layer_skip_{name}_{datetime.datetime.now():%F_%H-%M-%S}.log"

model_args = [
    "model_path='GSAI-ML/LLaDA-8B-Instruct'",
    "gen_length=256",
    "steps=256",
    "block_length=32",
    "threshold=0.9",
    "use_cache=True",
    "layer_skip=True",
    f"layer_skip_threshold={threshold}",
    "show_speed=True",
]

cmd = f"""CUDA_VISIBLE_DEVICES={gpu} accelerate launch eval_llada.py \\
    --tasks gsm8k --num_fewshot 5 --limit {limit} \\
    --confirm_run_unsafe_code --model llada_dist \\
    --model_args {','.join(model_args)} \\
    --output_path evals_results/layer_skip/manual-{name} --log_samples"""

print(f"Running: {name}")
print(f"Log: {log_file}")
print(f"Command: {cmd[:200]}...")

# Uncomment to run:
# p = subprocess.Popen(cmd, shell=True, stdout=open(log_file, "w"), stderr=subprocess.STDOUT)
# p.wait()
# print(f"Finished (exit code: {p.returncode})")

# %% [markdown]
# ## 5. 对比分析

# %%
import matplotlib.pyplot as plt
import numpy as np

# 从上面的 results 中提取数据进行可视化
# 需要先运行 Section 3 获取 results

if results:
    # 按 threshold 排序（从文件名提取）
    valid_results = [r for r in results if r['accuracy'] is not None and r['skip_rate'] is not None]
    
    if valid_results:
        # 提取 threshold 值
        for r in valid_results:
            th_match = re.search(r'th(\d+)', r['name'])
            r['threshold'] = int(th_match.group(1)) / 1000 if th_match else 0
        
        valid_results.sort(key=lambda x: x['threshold'])
        
        thresholds = [r['threshold'] for r in valid_results]
        accuracies = [r['accuracy'] for r in valid_results]
        skip_rates = [r['skip_rate'] for r in valid_results]
        speeds = [r['tokens_per_sec'] for r in valid_results]
        
        fig, axes = plt.subplots(1, 3, figsize=(15, 5))
        
        # Accuracy vs Threshold
        axes[0].plot(thresholds, accuracies, 'bo-', linewidth=2, markersize=8)
        axes[0].set_xlabel('Layer Skip Threshold')
        axes[0].set_ylabel('Accuracy (%)')
        axes[0].set_title('Accuracy vs Threshold')
        axes[0].grid(True, alpha=0.3)
        
        # Skip Rate vs Threshold
        axes[1].plot(thresholds, skip_rates, 'ro-', linewidth=2, markersize=8)
        axes[1].set_xlabel('Layer Skip Threshold')
        axes[1].set_ylabel('Skip Rate (%)')
        axes[1].set_title('Skip Rate vs Threshold')
        axes[1].grid(True, alpha=0.3)
        
        # Speed vs Threshold
        axes[2].plot(thresholds, speeds, 'go-', linewidth=2, markersize=8)
        axes[2].set_xlabel('Layer Skip Threshold')
        axes[2].set_ylabel('Tokens/second')
        axes[2].set_title('Speed vs Threshold')
        axes[2].grid(True, alpha=0.3)
        
        plt.tight_layout()
        plt.savefig('nlogs/layer_skip_analysis.png', dpi=150)
        plt.show()
        
        print("\n图表已保存至 nlogs/layer_skip_analysis.png")
    else:
        print("没有找到有效的结果数据")
else:
    print("请先运行 Section 3 获取结果数据")
